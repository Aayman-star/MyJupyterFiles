# %%
myList=['aayman','kanza','ammi','chintoo']
print(myList)

# %%
myList.append("panther")
print(myList)

# %%
myList=myList+["billoo","pari"]

# %%
print(myList)

# %%
myList.insert(3,"Tiger")

# %%
print(myList)

# %%
pets=myList[3:len(myList)]
print(len(myList))
print(len(pets))
print(pets)

# %%
hoomans=myList[:3]
print(hoomans)

# %%
hoomans.insert(0,"ammi")
print(hoomans)

# %%
hoomans=hoomans[:3]

# %%
print(hoomans)

# %%
print(myList[3:])

# %%
pets.remove("Tiger")
print(pets)

# %%
del pets[2]
print(pets)

# %%
print(pets)

# %%
print(hoomans)

# %%
hoomans.append(pets.pop())
print(hoomans)

# %%
print(pets)

# %%
pets.append(hoomans.pop())
print(pets)
print(hoomans)

# %%
hoomans.append(pets.pop())
print(hoomans)

# %%
print(pets)

# %%
pets.insert(0,pets.pop())
print(pets)

# %%
print(pets)

# %%
pets1=[]
for baby in pets:
    pets1.append(baby.title())
    
print(pets1)

# %%
aria = "light"
new_list = [aria]
print(new_list)

# %%
a = "Aayman"
print(a)

# %%
a = a.split()

# %%
print(a)

# %%
print(a)

# %%
a = "Aayman"
a = a.split()
print(a)
print(len(a))

# %%
a = "aayman"
print(len(a))

# %%
a = "lliw srettel lla sekat secapS naht si eb ataK eb fo a sekat eman ro srettel eno nehw sgnirtS ni tneserp si rettel naht tsuJ evif eht"
print(a[len(a)-1::-1])

# %%
a = "Hey Fellow Warriors"
b = a.split(" ")
print(len(a))
print(b)
print(len(b))
print(len(b[1]))
c = b[1][len(b[1])-1::-1]
print(c)

# %%
a = input("Enter a String: ")
reverse = []

for word in a.split():
    if len(word) >= 5:
        reverse.append(word[::-1])
    else:
        reverse.append(word)
        
print("Reversed string : "," ".join(reverse))

# %%
a = "Hey"
b = a.split(" ")
print(len(b[0]))

# %%
a = input("Enter a list of values: ")
print(a)
print(a.split(" "))
print("".join(a))

# %%
a = "Hey There people"
x = []
for word in a.split():
    x.append(word +" " +  "world")
print(" ".join(x))

# %%
t = "Hey"
print(t + "There")

# %%
x = "Hey there"
y = x.split(" ")
print(x[::-1])
print(x[::])
print(y[::-1])
print(y[::])

# %%
a =  input("Enter a string: ")
print(" ".join([x[::-1] if len(x) >= 5 else x for x in a.split(" ")]))

# %%
a = input("Enter some values : ")
a = a.split(" ")
print(a)
b = []
i = 0
while(i < len(a)):
    if type(a[i]) == int:
        b.append(a[i])
i = i+1
    
print(b)

# %%
x = isinstance(5,str)
print(x)

# %%
a = [1,  2, 'a', 'b']
b =[]
for x in a:
    if isinstance(x,int):
        b.append(x)

print(b)
# Out:
# [1, 2]

# %%
a , b = 100, 20
minn = a if a < b else b
print(minn)
# Out:
# 20

# %%
##Filtering an array using filter function
a = [1, 2, 'a', 'b']
b = []

def Fillter(x):
    return True if isinstance(x, int) else False

flist = filter(Fillter, a)
for i in flist:
    print(i)
# Out:
# 1
# 2

# %%
a = [1, 2, 'a', 'b']
def flist(a):
    return [x for x in a if isinstance(x, int)]
print(flist(a))
# Out:
# [1, 2]

# %%
a = 45
b = str(a)
print(int(b[0]) + int(b[1]))
# Out:
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-50145bbf4b4b> in <module>
#       2 b = str(a)
#       3 print(int(b[0]) + int(b[1]))
# ----> 4 sum(int(b[::]))
#
# TypeError: 'int' object is not iterable

# %%
a = "451"

while len(a) > 1:
    b = []
    Sum = 0
    for x in a:
        b.append(x)

    print(b)
    for y in b:
        Sum = Sum + int(y)

a = str(Sum)
print(Sum)
print(len(str(Sum)))
# Out:
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ['4', '5', '1']
# ...

# %%
x = 8
y = 1
while x > 1:
    y =y * x
    x = x- 1
    
print(y)
# Out:
# 40320
